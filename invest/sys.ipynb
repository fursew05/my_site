# %%
import invest

# %%
df2 = invest.load_data('AAPL')

# %%
class2 = invest.Invest(df2,_col='Close')

# %%
class2.buyandhold()
# Out:
# 2010-01-01 00:00:00
# 2025-03-26 17:44:29.112313
# Close
# 바이앤홀드 df :  3830
# 2010-01-01부터
#           2025-03-26까지
#           buyandhold의 수익율은 34.7420109800206입니다
# 투자기간 : 2010-01-01 00:00:00 ~ 2025-03-26 17:44:29.112313, 총 수익율 : 34.7420109800206
#                           Close  daily_rtn    acc_rtn
# Date
# 2010-01-04 05:00:00    6.440330   1.000000   1.000000
# 2010-01-05 05:00:00    6.451467   1.001729   1.001729
# 2010-01-06 05:00:00    6.348846   0.984093   0.985795
# 2010-01-07 05:00:00    6.337109   0.998151   0.983973
# 2010-01-08 05:00:00    6.379240   1.006648   0.990515
# ...                         ...        ...        ...
# 2025-03-19 04:00:00  215.240005   1.011989  33.420651
# 2025-03-20 04:00:00  214.100006   0.994704  33.243641
# 2025-03-21 04:00:00  218.270004   1.019477  33.891124
# 2025-03-24 04:00:00  220.729996   1.011270  34.273090
# 2025-03-25 04:00:00  223.750000   1.013682  34.742011
#
# [3830 rows x 3 columns]

# %%
class2.bollinger()
# Out:
# 매수일 : 2010-08-24 04:00:00, 매수가 : 7.2203569412231445
# 매도일 : 2010-09-08 04:00:00, 매도가 : 7.9122114181518555
# 수익율 : 1.0958199826630053
# 매수일 : 2011-03-16 04:00:00, 매수가 : 9.93118953704834
# 매도일 : 2011-07-01 04:00:00, 매도가 : 10.329927444458008
# 수익율 : 1.0401500651983506
# 매수일 : 2011-11-14 05:00:00, 매수가 : 11.413299560546875
# 매도일 : 2011-12-27 05:00:00, 매도가 : 12.2339506149292
# 수익율 : 1.0719030504744766
# 매수일 : 2012-04-16 04:00:00, 매수가 : 17.45819854736328
# 매도일 : 2012-06-18 04:00:00, 매도가 : 17.628231048583984
# 수익율 : 1.0097394070046468
# 매수일 : 2012-10-08 04:00:00, 매수가 : 19.28728675842285
# 매도일 : 2013-07-29 04:00:00, 매도가 : 13.765028953552246
# 수익율 : 0.7136840513630561
# 매수일 : 2013-09-11 04:00:00, 매수가 : 14.47230052947998
# 매도일 : 2013-10-18 04:00:00, 매도가 : 15.746527671813965
# 수익율 : 1.0880459288237134
# 매수일 : 2014-01-03 05:00:00, 매수가 : 16.83721923828125
# 매도일 : 2014-03-25 04:00:00, 매도가 : 17.063560485839844
# 수익율 : 1.013442911466282
# 매수일 : 2014-10-15 04:00:00, 매수가 : 21.60406494140625
# ...

# %%
class2.momentum()
# Out:
# c:\Users\fursew\AppData\Local\Programs\Python\Python313\Lib\site-packages\invest\quant\momentum.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF1'] = result.shift(1)[col]
# c:\Users\fursew\AppData\Local\Programs\Python\Python313\Lib\site-packages\invest\quant\momentum.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['BF2'] = result.shift(_momentum)[col]
# ...
